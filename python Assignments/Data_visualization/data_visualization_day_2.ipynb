# %% [markdown]
# ##### import the titanic dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL 3400\Downloads\1569615-1545342-Data_visualization\Data_visualization\Data_visualization_day_2\titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# Unnamed: 15    float64
# dtype: object

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the fare of class.

# %%
### code here
gp=df.groupby('class')['fare'].mean()
gp.plot(kind="bar")
# Out:
# <Axes: xlabel='class'>

# %% [markdown]
# ###### 2. Write a Python program to display a horizontal bar chart of the fare of class.

# %%
### code here
gp.plot(kind="barh")
# Out:
# <Axes: ylabel='class'>

# %% [markdown]
# ###### 3. Write a Python program to display a bar chart of the fare of class. Use different color for each bar.

# %%
### code here
gp.plot(kind='bar',color=['purple','black','green'])
# Out:
# <Axes: xlabel='class'>

# %% [markdown]
# ###### 4. Write a Python program to create a pie chart of the fare of class.

# %%
### code here
gp.plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='fare'>

# %% [markdown]
# ######5. Write a Python program to display a count plot of all categorical columns.

# %%
### code here
cat_cols=df.select_dtypes(['object','bool'])

# %%
for col in cat_cols:
    sns.countplot(df[col])  
    plt.show()

# %% [markdown]
# ###### 6. Write a Python program to display a factor plot of ( pclass vs embarked). hist (kind = 'count')

# %%
  #### code here
#factorplot was a versatile function in Seaborn for categorical data visualizations, but it has been deprecated.
sns.catplot(x="pclass", hue="embarked", data=df, kind="count")

# %% [markdown]
# ###### 7. Write a Python programming to display a factor plot of ( pclass vs sex). hist (kind = 'count')

# %%
### code here
sns.catplot(x="pclass", hue="sex", data=df, kind="count")

# %% [markdown]
# ###### 8. Write a Python programming to display a factor plot of ( embarked vs sex). hist (kind = 'count')

# %%
### code here 
sns.catplot(x="embarked", hue="sex", data=df, kind="count")

# %% [markdown]
# ###### 9. Write a Python program to display distribution plot for all numberical columns.

# %%
### code here
num_cols=df.select_dtypes(['int64','float64'])
for col in num_cols:
  # Adjust figure size as needed
    sns.kdeplot(df[col])  # KDE is for Kernel Density Estimate
    plt.show()
# Out:
# C:\Users\DELL 3400\AppData\Local\Temp\ipykernel_17428\3425558656.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df[col])  # KDE is for Kernel Density Estimate

# %% [markdown]
# ###### 10. Write a Python program to display boxplot of age, pclass and hue = gender.

# %%
### code here
sns.boxplot(x='pclass', y='age', hue='sex', data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ##### Bonus Question

# %% [markdown]
# ### 1. What are the plots we can create on numerical columns.

# %% [markdown]
# ### write here
# - **histogram plot**
# - **Box plot**
# - **Kde/density plot**
# - **violin plot**

# %% [markdown]
# ### 2. What are the plots we can create on categorical columns.

# %% [markdown]
# - **Bar(count) plot**
# - **Pieplot**
