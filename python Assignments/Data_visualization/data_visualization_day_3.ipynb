# %% [markdown]
# ##### import tips dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL 3400\Downloads\1569615-1545342-Data_visualization\Data_visualization\Data_visualization_day_3\tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the total bill of Gender and write the intuition about the plot.

# %%
### code here
gp=df.groupby('sex')['total_bill'].mean()
gp.plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ### intution about the plot
# - Males spend more compares to women

# %% [markdown]
# ###### 2. Write a Python program to display a box plot of the total bill of day and hue = "smoker" and write the intuition about the plot.

# %%
#### code here
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
- Total bill paid  is more on sunday and saturday by smokers compared to other days.

# %% [markdown]
# ##### 3. Write a Python program to display a violin plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here
sns.violinplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# - according to plot Men are spending more money but it is higher in saturday and sunday comared to other days

# %% [markdown]
# ##### 4. Write a Python program to display a strip plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here 
sns.stripplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# - Men are spending more money compare to women

# %% [markdown]
# ##### 5. Write a Python program to display heat map of dataframe and write the intuition about the plot.

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
### code here
df1=df[['total_bill','tip','size']].corr()
sns.heatmap(df1)
plt.show()

# %%
- it shows how the numeriacal cols are correlates to each other.

# %% [markdown]
# ##### 6. Write a Python program to display scatter plot of total bill of tip and write the intuition about the plot.

# %%
### code here
sns.scatterplot(x='tip',y='total_bill',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# - If the total_bill is high tip is also high.

# %% [markdown]
# ##### 7. Write a Python program to display density plot of all numerical columns from the dataframe and write the intution about plot.

# %%
### code here
num_cols=df.select_dtypes(['int64','float64'])
for col in num_cols:
  # Adjust figure size as needed
    sns.kdeplot(df[col])  # KDE is for Kernel Density Estimate
    plt.show()

# %% [markdown]
# ##### 8. Write a Python program to calculate average total bills by days and display top 4 days by plot.

# %%
### code here
gp=df.groupby('day')['total_bill'].mean()
gp.plot(kind='bar')
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# #### Bonus Question

# %% [markdown]
# ###### 1. What is Histogram chart ?

# %% [markdown]
# #### write here
#
# **1. Histogram**
#
# -
# What it shows: A histogram represents the frequency distribution of a single numerical variable, breaking the data into bins and showing how many  -    data points fall within each bin.
# nsformation).

# %% [markdown]
# **What we understand:**
#
# - Skewness (left or right skewed distribution).
# - Concentration of data points (high or low frequency bins).
# - Spread and range of the variable.
# - Presence of outliers (extreme values).
#
# **How it helps in analysis:**
#
# - Helps you understand the shape and spread of the data.
# - Allows you to detect if data is normally distributed or not.
# - Can highlight any potential need for transformation (e.g., log transformation).

# %% [markdown]
# ##### 2. What is box plot ?

# %% [markdown]
# ### write here
# **What it shows:**
# - Boxplots summarize the distribution of a variable and highlight potential outliers using quartiles and whiskers.
#
# **What we understand:**
#
# - Median (central tendency).
# - IQR (Interquartile Range): The range between Q1 (25th percentile) and Q3 (75th percentile).
# - Outliers: Shown as points outside the whiskers.
#
# **How it helps in analysis:**
#
# - Detects outliers and extreme values.
# - Visualizes the spread and symmetry of data.
# - Useful for comparing distributions across multiple groups.

# %% [markdown]
# ##### 3. What are the plots we can use for univeriate analysis.

# %% [markdown]
# ### write here
# - **Histogram**: Shows the distribution of continuous numerical data.
# - **Box Plot**: Provides a summary of a variable's distribution, including outliers.
# - **Violin Plot**: Combines the features of a box plot and a KDE, showing both the distribution and the density of the data.
# - **Density Plot (KDE)**: Shows the continuous probability density function of a variable.
# - **Bar Plot**: Used for categorical data to show the frequency of each category.
# - **Pie Chart**: Displays the relative proportions of categories in a dataset.
# - **Count Plot**: Displays the count of occurrences of each category, specifically for categorical variables.
# - **Strip Plot:** Shows the distribution of categorical variables by plotting individual data points.

# %% [markdown]
# ##### 4. What are the plots we can use for bivariate analysis.

# %% [markdown]
# ### code here
# - **Scatter Plot**: Shows relationships between two continuous variables.
# - **Line Plot**: Shows the relationship between two continuous variables over a time-based or ordered domain.
# - **Heatmap (Correlation Matrix)**: Visualizes the correlation between multiple continuous variables using color gradients.
# - **Pair Plot (Scatterplot Matrix):** Shows relationships between all pairs of variables in a dataset.
# - **Bar Plot (Categorical vs Continuous):** Compares the means of a continuous variable across different categories.
# - **Box Plot (Categorical vs Continuous):** Shows the distribution of a continuous variable across different categories.
# - **Strip Plot (Categorical vs Continuous):** Displays individual data points to visualize the distribution across categories.

# %% [markdown]
# ###### 5. What are plot we can use for multivariate analysis.

# %% [markdown]
# ### code here
# - **Pair Plot (Scatterplot Matrix):** Shows scatter plots for all pairs of variables and univariate distributions on the diagonal. Useful for detecting relationships between multiple pairs of variables.
# - **Heatmap:** Visualizes correlations or relationships between multiple variables with a color gradient.
