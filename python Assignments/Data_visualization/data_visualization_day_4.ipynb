# %% [markdown]
# ##### import required libraries.
# ##### laod diamond dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL 3400\Downloads\1569615-1545342-Data_visualization\Data_visualization\Data_visualization_day_4\diamonds.csv")

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %% [markdown]
# #### Write a Python program to display all Univariate Plots from the dataframe.
#
#
# 1.   Numeric based plots
# 2.   Categorical based plots

# %% [markdown]
# # 1.Numeric based plots

# %% [markdown]
# #### histogram plot

# %%
#### code here
df["carat"].hist(bins=30)
# Out:
# <Axes: >

# %% [markdown]
# #### Box plot

# %%
df["carat"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# #### kde/density plot

# %%
#### code here
df['carat'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #### scatter plot

# %%
plt.scatter(df['carat'],df.index)
plt.show()

# %% [markdown]
# #### violin plot

# %%
sns.violinplot(df['carat'])
# Out:
# <Axes: ylabel='carat'>

# %% [markdown]
# # 2.Categorical Data

# %% [markdown]
# #### BAR graph

# %%
df["cut"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cut'>

# %% [markdown]
# #### pie chart

# %%
df["cut"].value_counts().plot(kind='pie',autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### Write a Python program to display all Bivariate plots from the dataframe.
#
# 1.   Numeric to Numeric based plots
# 2.   Numeric to Categorical Plots
# 3.   Categorical to Categorical Plots

# %% [markdown]
# # 1.Numeric to Numeric based plots

# %% [markdown]
# #### scatter plot

# %%
### code here
sns.scatterplot(x='depth',y='table',data=df)
# Out:
# <Axes: xlabel='depth', ylabel='table'>

# %%
### code here
sns.lineplot(x='table',y='depth',data=df)
# Out:
# <Axes: xlabel='table', ylabel='depth'>

# %% [markdown]
# # 2.Numeric to Categorical Plots

# %%
sns.boxplot(x='cut',y='carat',data=df)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
sns.barplot(x='cut',y='carat',data=df)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
sns.violinplot(x='cut',y='carat',data=df)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %% [markdown]
# # 3.   Categorical to Categorical Plots

# %% [markdown]
# #### bar plot

# %%
df[['clarity','cut']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='clarity,cut'>

# %% [markdown]
# #### Write a Python program to display all Multivariate plots from the dataframe.

# %%
sns.stripplot(x='cut',y='carat',hue='cut',data=df)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
df1=df.select_dtypes('number')
df1=df1.corr()
sns.heatmap(df1)
# Out:
# <Axes: >

# %%
sns.boxplot(x='cut',y='carat',hue='cut',data=df)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %% [markdown]
# ##### hint - https://www.python-graph-gallery.com/
