# %% [markdown]
# # pandas case study

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\DELL 3400\Downloads\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# **Q1. Rename the columns of the dataset to 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', and 'Species'.**

# %%
df=df.rename(columns={'SepalLengthCm':'SepalLength','SepalWidthCm':'SepalWidth','PetalLengthCm':'PetalLength','PetalWidthCm':'PetalWidth','Species':'species'})
df.columns
# Out:
# Index(['Id', 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth',
#        'species'],
#       dtype='object')

# %% [markdown]
# **Q2.**
# **a.Set the index of the DataFrame to the 'Species' column.**
#
# **b.Retrieve the first 10 rows of the DataFrame using integer-based indexing**

# %%
#a
df.set_index("species",inplace=True)
df
# Out:
#                  Id  SepalLength  SepalWidth  PetalLength  PetalWidth
# species
# Iris-setosa       1          5.1         3.5          1.4         0.2
# Iris-setosa       2          4.9         3.0          1.4         0.2
# Iris-setosa       3          4.7         3.2          1.3         0.2
# Iris-setosa       4          4.6         3.1          1.5         0.2
# Iris-setosa       5          5.0         3.6          1.4         0.2
# ...             ...          ...         ...          ...         ...
# Iris-virginica  146          6.7         3.0          5.2         2.3
# Iris-virginica  147          6.3         2.5          5.0         1.9
# Iris-virginica  148          6.5         3.0          5.2         2.0
# Iris-virginica  149          6.2         3.4          5.4         2.3
# Iris-virginica  150          5.9         3.0          5.1         1.8
#
# [150 rows x 5 columns]

# %%
#b.
set=df.reset_index().head(10)
set
# Out:
#    index  Id  SepalLength  SepalWidth  PetalLength  PetalWidth      species
# 0      0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1      1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2      2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3      3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4      4   5          5.0         3.6          1.4         0.2  Iris-setosa
# 5      5   6          5.4         3.9          1.7         0.4  Iris-setosa
# 6      6   7          4.6         3.4          1.4         0.3  Iris-setosa
# 7      7   8          5.0         3.4          1.5         0.2  Iris-setosa
# 8      8   9          4.4         2.9          1.4         0.2  Iris-setosa
# 9      9  10          4.9         3.1          1.5         0.1  Iris-setosa

# %% [markdown]
# **Q3.**
# **a.Slice the DataFrame to display rows with 'PetalWidth' greater than 2.5.**
#
# **b.Slice the DataFrame to display columns 'SepalLength' and 'SepalWidth' for the first 5 rows.**

# %%
#a
#there are no rows with 'PetalWidth' greater than 2.5.
df[df['PetalWidth']>2.5]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLength, SepalWidth, PetalLength, PetalWidth, species]
# Index: []

# %%
#b
df[0:5][['SepalLength','SepalWidth']]
# Out:
#    SepalLength  SepalWidth
# 0          5.1         3.5
# 1          4.9         3.0
# 2          4.7         3.2
# 3          4.6         3.1
# 4          5.0         3.6

# %%
#using iloc
df.iloc[0:5,0:2]
# Out:
#    Id  SepalLength
# 0   1          5.1
# 1   2          4.9
# 2   3          4.7
# 3   4          4.6
# 4   5          5.0

# %%
#using loc
df.loc[0:4][['SepalLength','SepalWidth']]
# Out:
#    SepalLength  SepalWidth
# 0          5.1         3.5
# 1          4.9         3.0
# 2          4.7         3.2
# 3          4.6         3.1
# 4          5.0         3.6

# %% [markdown]
# **Q4.**
# **a.Filter the DataFrame to show only rows where 'Species' is 'versicolor'.**
#
# **b.Filter the DataFrame to show rows where 'PetalLength' is greater than 4 and 'SepalWidth' is less than 3.**

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#a
df[df['species']=='Iris-versicolor']
# Out:
#      Id  SepalLength  SepalWidth  PetalLength  PetalWidth          species
# 50   51          7.0         3.2          4.7         1.4  Iris-versicolor
# 51   52          6.4         3.2          4.5         1.5  Iris-versicolor
# 52   53          6.9         3.1          4.9         1.5  Iris-versicolor
# 53   54          5.5         2.3          4.0         1.3  Iris-versicolor
# 54   55          6.5         2.8          4.6         1.5  Iris-versicolor
# 55   56          5.7         2.8          4.5         1.3  Iris-versicolor
# 56   57          6.3         3.3          4.7         1.6  Iris-versicolor
# 57   58          4.9         2.4          3.3         1.0  Iris-versicolor
# 58   59          6.6         2.9          4.6         1.3  Iris-versicolor
# 59   60          5.2         2.7          3.9         1.4  Iris-versicolor
# 60   61          5.0         2.0          3.5         1.0  Iris-versicolor
# ...

# %%
#b
df[(df['PetalLength']>4) & (df['SepalWidth']<3)]
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth          species
# 54    55          6.5         2.8          4.6         1.5  Iris-versicolor
# 55    56          5.7         2.8          4.5         1.3  Iris-versicolor
# 58    59          6.6         2.9          4.6         1.3  Iris-versicolor
# 63    64          6.1         2.9          4.7         1.4  Iris-versicolor
# 67    68          5.8         2.7          4.1         1.0  Iris-versicolor
# 68    69          6.2         2.2          4.5         1.5  Iris-versicolor
# 72    73          6.3         2.5          4.9         1.5  Iris-versicolor
# 73    74          6.1         2.8          4.7         1.2  Iris-versicolor
# 74    75          6.4         2.9          4.3         1.3  Iris-versicolor
# 76    77          6.8         2.8          4.8         1.4  Iris-versicolor
# 78    79          6.0         2.9          4.5         1.5  Iris-versicolor
# ...

# %% [markdown]
# **Q5.**
# **a.Calculate the minimum 'PetalLength' across all species.**
#
# **b.Calculate the maximum 'SepalWidth' across all species.**

# %%
#a
df['PetalLength'].unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
df['PetalLength'].min()
# Out:
# 1.0

# %%
#b
df['SepalWidth'].unique()
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 2.9, 3.7, 4. , 4.4, 3.8, 3.3,
#        4.1, 4.2, 2.3, 2.8, 2.4, 2.7, 2. , 2.2, 2.5, 2.6])

# %%
df['SepalWidth'].max()
# Out:
# 4.4

# %% [markdown]
# **Q6.**
# **a.Calculate the sum of values along axis=1 (row-wise).**
#
# **b.Calculate the mean of values along axis=0 (column-wise).**

# %%
df[['Id','SepalLength','SepalWidth','PetalLength','PetalWidth']].mean(axis=0)
# Out:
# Id             75.500000
# SepalLength     5.843333
# SepalWidth      3.054000
# PetalLength     3.758667
# PetalWidth      1.198667
# dtype: float64

# %%
df[['Id','SepalLength','SepalWidth','PetalLength','PetalWidth']].sum(axis=1)
# Out:
# 0       11.2
# 1       11.5
# 2       12.4
# 3       13.4
# 4       15.2
#        ...
# 145    163.2
# 146    162.7
# 147    164.7
# 148    166.3
# 149    165.8
# Length: 150, dtype: float64

# %% [markdown]
# **Q7. Add a new column 'PetalArea' calculated as the product of 'PetalLength' and 'PetalWidth'.**

# %%
df['PetalArea']=df['PetalLength']*df['PetalWidth']
df
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         species  \
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
#      PetalArea
# 0         0.28
# 1         0.28
# 2         0.26
# ...

# %% [markdown]
# **Q8. Convert the 'SepalLength' column to float dtype using astype.**

# %%
df['SepalLength'].astype('float')
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLength, Length: 150, dtype: float64

# %%
df
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         species  \
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
#      PetalArea
# 0         0.28
# 1         0.28
# 2         0.26
# ...

# %% [markdown]
# **Q9. Query the DataFrame to show rows where 'PetalLength' is greater than 'SepalLength'.**

# %%
df[df['PetalLength']>df['SepalLength']]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLength, SepalWidth, PetalLength, PetalWidth, species, PetalArea]
# Index: []

# %% [markdown]
# **Q10. Apply a function to calculate the difference between 'PetalLength' and 'SepalLength' for each row.**

# %%
def diff(row):
    return row['PetalLength']-row['SepalLength']
df['difference']=df.apply(diff,axis=1)
df
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         species  \
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
#      PetalArea  difference
# 0         0.28        -3.7
# ...

# %%
df['difference']=df.apply(lambda row:row['PetalLength']-row['SepalLength'],axis=1)
df
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         species  \
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
#      PetalArea  difference
# 0         0.28        -3.7
# ...

# %% [markdown]
# **Q11.**
# **a.Find the top 3 rows with the largest 'PetalLength'.**
#
# **b.Find the top 3 rows with the smallest 'SepalWidth'.**

# %%
df['PetalLength'].max()
# Out:
# 6.9

# %%
#a
max_3=df.sort_values(by='PetalLength',ascending=False)
max_3.head(3)
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         species
# 118  119          7.7         2.6          6.9         2.3  Iris-virginica
# 122  123          7.7         2.8          6.7         2.0  Iris-virginica
# 117  118          7.7         3.8          6.7         2.2  Iris-virginica

# %%
#b
min_3=df.sort_values(by='SepalWidth',ascending=True)
min_3.head(3)
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth          species  \
# 60    61          5.0         2.0          3.5         1.0  Iris-versicolor
# 62    63          6.0         2.2          4.0         1.0  Iris-versicolor
# 119  120          6.0         2.2          5.0         1.5   Iris-virginica
#
#      PetalArea  difference
# 60         3.5        -1.5
# 62         4.0        -2.0
# 119        7.5        -1.0

# %% [markdown]
# **Q12.**
# **a.Sort the DataFrame by 'PetalWidth' in ascending order.**
#
# **b.Sort the DataFrame by 'SepalLength' in descending order**

# %%
#a
petalw=df.sort_values(by='PetalWidth',ascending=True)
petalw
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         species
# 32    33          5.2         4.1          1.5         0.1     Iris-setosa
# 13    14          4.3         3.0          1.1         0.1     Iris-setosa
# 37    38          4.9         3.1          1.5         0.1     Iris-setosa
# 9     10          4.9         3.1          1.5         0.1     Iris-setosa
# 12    13          4.8         3.0          1.4         0.1     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 140  141          6.7         3.1          5.6         2.4  Iris-virginica
# 114  115          5.8         2.8          5.1         2.4  Iris-virginica
# 100  101          6.3         3.3          6.0         2.5  Iris-virginica
# 144  145          6.7         3.3          5.7         2.5  Iris-virginica
# 109  110          7.2         3.6          6.1         2.5  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#b
sepall=df.sort_values(by='SepalLength',ascending=False)
sepall
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth         species
# 131  132          7.9         3.8          6.4         2.0  Iris-virginica
# 135  136          7.7         3.0          6.1         2.3  Iris-virginica
# 122  123          7.7         2.8          6.7         2.0  Iris-virginica
# 117  118          7.7         3.8          6.7         2.2  Iris-virginica
# 118  119          7.7         2.6          6.9         2.3  Iris-virginica
# ..   ...          ...         ...          ...         ...             ...
# 41    42          4.5         2.3          1.3         0.3     Iris-setosa
# 42    43          4.4         3.2          1.3         0.2     Iris-setosa
# 38    39          4.4         3.0          1.3         0.2     Iris-setosa
# 8      9          4.4         2.9          1.4         0.2     Iris-setosa
# 13    14          4.3         3.0          1.1         0.1     Iris-setosa
#
# [150 rows x 6 columns]
